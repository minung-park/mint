# %% [markdown]
# ## Training
# 학습 곡선, 트레이닝 스크립트
# 트레이닝 configure

# %% [markdown]
# ## Evaluation
# 결과물 확인

# %% [markdown]
# ## REPL 테스트
# 바로 테스트 할 수 있도록 노트북으로 구성

# %% [markdown]
# ## Training

# %%
import os
import json
import codecs
import unicodedata

home_path = os.path.expanduser('~')
root_dir = home_path + "/origin_neural-belief-tracker"

ko_file = root_dir+"/data/woz/woz_train_ko.json"
ko_datas = json.load(codecs.open(ko_file, 'r', 'cp949', 'ignore'))

for i in range(30):
    dialogues = ko_datas[i]["dialogue"] #data["dialogue"]
    for dialogue in dialogues:
        print 'sys: ', dialogue["system_transcript"]
        print 'user: ', dialogue["transcript"]
# Out:
# sys:
# user:  마을에 eritrean 레스토랑이 있습니까?
# sys:  아니, 마을에는 에리트레아 식당이 없다. 다른 레스토랑을 드시겠습니까?
# user:  중국 음식은 어떻습니까?
# sys:  다양한 중국 식당이 있으며 지역 특혜 또는 가격 선호도가 좁습니까?
# user:  나는 동쪽 마을을 원해.
# sys:  Yu Garden은 동쪽 지역의 중국 레스토랑입니다.
# user:  Yu Garden의 주소, 전화 번호 및 우편 번호를 얻을 수 있습니까?
# sys:  전화 번호는 01223 248882, 주소 및 우편 번호는 529 Newmarket Road Fen Ditton CB 5, 8 PA
# user:  고맙습니다. 그것이 내가 필요한 모든 정보입니다. 안녕!
# sys:
# user:  안녕하세요, 저는 훌륭한 독일 식당을 찾고 있습니다.
# sys:  독일 식당이 나열되어 있지 않습니다. 또 다른 선호도가 있습니까?
# user:  유럽 어때요?
# sys:  마을의 어느 지역?
# user:  나는 상관 없다.
# sys:  그 설명에 맞는 10 개의 레스토랑이 있습니다. 가격 선호도가 있습니까?
# user:  가장 비싼 주소, 전화 번호 및 지역을 사용할 수 있습니까?
# sys:  캠브리지 롯지 호텔은 캠브리지 롯지 호텔 139 Huntingdon Road City Centre에 위치한 서쪽 지역에 비싼 것으로 열거되어 있습니다. 전화 번호는 01223 355166입니다.
# user:  고마워, 안녕.
# sys:
# user:  나는 호주 음식을 제공하는 값 비싼 가격대의 레스토랑을 찾고 있습니다.
# sys:  요청에 맞는 식당이 없습니다. 다른 종류의 레스토랑을 찾는데 도와 줄 수 있습니까?
# user:  지중해 음식을 찾고 싶습니다. 주소와 전화 번호를 알아야합니다.
# ...
