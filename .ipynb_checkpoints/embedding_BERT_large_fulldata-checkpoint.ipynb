# %%
#-*- coding: utf-8 -*-
import os
import codecs
import pandas as pd

import copy

# %%
from bert_serving.client import BertClient
bc = BertClient(ip='192.168.100.13', check_version=False, check_length=False)

# %%
import json
import codecs

training_file = os.getcwd() +'/data/woz/woz_train_en.json'

list = json.load(codecs.open(training_file, 'r', 'utf-8', 'ignore'))

total_utter= []
utterances = []
state_list = []

for data in list:
    dial_list = data['dialogue']
    state = ''
    
    for dial_text in dial_list:
        system_transcript = dial_text['system_transcript'] # system_utterance
        transcript = dial_text['transcript'].lower() # user_utterance
        belief_states = dial_text['turn_label']
        utterances.append(transcript)
        
        total_utter.append(transcript)
        if system_transcript != '':
            total_utter.append(system_transcript)
        
        cur_states = ''
        if belief_states:
            for belief_state in belief_states:
                if belief_state[0] == 'request':
                    actions = 'request'
                    slots = belief_state[1]
                else:
                    actions = 'inform'
                    slots = belief_state[0]
                
                state = actions + ":" + slots
                cur_states += state+','
                #cur_states.append(state)
            
            state_list.append(cur_states) #state_list.append(tuple(cur_states))
        else:
            state_list.append(cur_states) #state_list.append(tuple(cur_states))

# %%
total_embedding = bc.encode(total_utter)
embeddings = pd.DataFrame(index=total_utter, data=total_embedding)
embeddings.to_csv('word-vectors/bert_large_sentences_embedding.csv')

# %%
embedding = bc.encode(utterances)

bert_sentence_embeddings = pd.DataFrame(index=utterances, data=embedding)
bert_sentence_embeddings.index.names = ['sentence']
bert_sentence_embeddings.head()
# Out:
#                                                         0         1     \
# sentence
# are there any eritrean restaurants in town?        -0.116978 -0.158745
# how about chinese food?                            -0.346118 -0.444916
# i would like the east part of town.                -0.156444 -0.183520
# could i get the address, phone number, and post... -0.400595 -0.126168
# thank you.  that is all the information i neede...  0.214376 -0.621695
#
#                                                         2         3     \
# sentence
# are there any eritrean restaurants in town?        -0.413718 -0.161291
# how about chinese food?                            -0.530923 -0.903273
# i would like the east part of town.                -0.429033 -1.034222
# could i get the address, phone number, and post... -0.209314 -0.481168
# thank you.  that is all the information i neede... -0.422750 -0.355247
#
#                                                         4         5     \
# sentence
# are there any eritrean restaurants in town?         0.135984 -0.326958
# how about chinese food?                            -0.424282 -0.481982
# i would like the east part of town.                -0.424093 -0.119959
# could i get the address, phone number, and post... -0.284953 -0.183087
# thank you.  that is all the information i neede...  0.137500 -0.327950
#
#                                                         6         7     \
# sentence
# are there any eritrean restaurants in town?         0.023142  0.266494
# how about chinese food?                             0.312920  0.571118
# i would like the east part of town.                 0.300322  0.454491
# could i get the address, phone number, and post...  0.114570  0.229087
# thank you.  that is all the information i neede...  0.412747  0.759212
#
#                                                         8         9     ...  \
# sentence                                                                ...
# are there any eritrean restaurants in town?        -0.208811  0.042468  ...
# how about chinese food?                            -0.055284  0.241288  ...
# i would like the east part of town.                -0.132526  0.413061  ...
# could i get the address, phone number, and post... -0.286130  0.352155  ...
# thank you.  that is all the information i neede...  0.030973  0.442599  ...
#
#                                                         1014      1015  \
# sentence
# are there any eritrean restaurants in town?        -0.091497  0.304171
# how about chinese food?                             0.057322  0.355964
# i would like the east part of town.                -0.040958  0.379732
# could i get the address, phone number, and post... -0.071776 -0.014903
# thank you.  that is all the information i neede...  0.047246  0.057518
#
#                                                         1016      1017  \
# sentence
# are there any eritrean restaurants in town?         0.081273 -0.245607
# how about chinese food?                             0.032526  0.109045
# i would like the east part of town.                -0.203519  0.061933
# could i get the address, phone number, and post... -0.188110  0.037200
# thank you.  that is all the information i neede... -0.191806  0.120869
#
#                                                         1018      1019  \
# sentence
# are there any eritrean restaurants in town?         0.030764  0.248127
# how about chinese food?                            -0.249084 -0.102280
# i would like the east part of town.                -0.429659  0.154310
# could i get the address, phone number, and post... -0.093228  0.154461
# thank you.  that is all the information i neede... -0.148298  0.419700
#
#                                                         1020      1021  \
# sentence
# are there any eritrean restaurants in town?        -0.092645 -0.000570
# how about chinese food?                            -0.009053  0.120145
# i would like the east part of town.                 0.164594 -0.032725
# could i get the address, phone number, and post... -0.153694  0.330254
# thank you.  that is all the information i neede...  0.270176 -0.033666
#
#                                                         1022      1023
# sentence
# are there any eritrean restaurants in town?        -0.081064  0.190998
# how about chinese food?                            -0.190414  0.014101
# i would like the east part of town.                 0.427470 -0.084749
# could i get the address, phone number, and post...  0.096650 -0.006873
# thank you.  that is all the information i neede...  0.592106  0.024707
#
# [5 rows x 1024 columns]

# %%
from sklearn.manifold import TSNE
import pickle

USE_PREMADE_TSNE = False

tsne_filepath = os.getcwd() + "/data/bert_large_usr_fulldata_tsne.pkl"

if not USE_PREMADE_TSNE:
    
    tsne = TSNE(random_state=0)
    tsne_points = tsne.fit_transform(bert_sentence_embeddings.values)
    with open(tsne_filepath, 'wb') as f:
        pickle.dump(tsne_points, f)
else:
    with open(tsne_filepath, 'rb') as f:
        tsne_points = pickle.load(f)

tsne_bert = pd.DataFrame(tsne_points, index=bert_sentence_embeddings.index, columns=['x_coord', 'y_coord'])

# %%
tsne_bert['state'] = state_list

# %%
tsne_bert.head()
# Out:
#                                                       x_coord    y_coord  \
# sentence
# are there any eritrean restaurants in town?         38.615631  11.376017
# how about chinese food?                             63.331375  -3.629289
# i would like the east part of town.                 36.635284 -16.371567
# could i get the address, phone number, and post...   9.134102  28.372196
# thank you.  that is all the information i neede... -33.718346  -2.739453
#
#                                                                                               state
# sentence
# are there any eritrean restaurants in town?                                            inform:food,
# how about chinese food?                                                                inform:food,
# i would like the east part of town.                                                    inform:area,
# could i get the address, phone number, and post...  request:postcode,request:phone,request:address,
# thank you.  that is all the information i neede...

# %% [markdown]
# ## 시각화 진행 - level 1: intent별로 분류

# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import HoverTool, ColumnDataSource, value

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
inform_tsne = tsne_bert[tsne_bert['state'].str.contains('inform') & ~tsne_bert['state'].str.contains('request')]
request_tsne = tsne_bert[tsne_bert['state'].str.contains('request') & ~tsne_bert['state'].str.contains('inform')]
joint_tsne = tsne_bert[tsne_bert['state'].str.contains('inform') & tsne_bert['state'].str.contains('request')]
etc_tsne = tsne_bert[~tsne_bert['state'].str.contains('request') & ~tsne_bert['state'].str.contains('inform')]

# %%
from bokeh.palettes import Pastel1

# create the plot and configure it
tsne_plot = figure(title='t-SNE BERT-large Sentence Embeddings - Level1: intent',
                   plot_width = 900,
                   plot_height = 600
                  ) #active_scroll='wheel_zoom'

colors = Pastel1[4]
tsne_plot.add_tools(HoverTool(tooltips = '@sentence'))
# adjust visual elements of the plot
tsne_plot.title.text_font_size = value('16pt')
tsne_plot.xaxis.visible = False
tsne_plot.yaxis.visible = False
tsne_plot.grid.grid_line_color = None
tsne_plot.outline_line_color = None


for i in range(4):
    plot_data = ''
    name = ''
    if i == 0:
        plot_data = ColumnDataSource(inform_tsne)
        name = 'inform'
    elif i == 1:
        plot_data = ColumnDataSource(request_tsne)
        name = 'request'
    elif i == 2:
        plot_data = ColumnDataSource(joint_tsne)
        name = 'joint'
    elif i == 3:
        plot_data = ColumnDataSource(etc_tsne)
        name = 'etc'
        
    tsne_plot.circle('x_coord', 'y_coord', source=plot_data,
                 #line_alpha=0.8, fill_alpha=0.1,
                 size=10, hover_line_color='black',
                 legend=name, color=colors[i]   
                )

tsne_plot.legend.location = "top_left"
tsne_plot.legend.click_policy="hide"

# show time!
show(tsne_plot);
# Out:
#   <div class="bk-root" id="4495bac8-39e5-4ad8-9400-3d46bf028088"></div>

# %% [markdown]
# ## 시각화 진행 - level 2: goal별로 분류

# %%
food_pattern = r'^((inform|request):food,){1}$' 
food_tsne = tsne_bert[tsne_bert['state'].str.match(food_pattern)]
price_pattern = r'^((inform|request):price range,){1}$' #r'(^.*(price range){1}(,){1})$'
price_tsne = tsne_bert[tsne_bert['state'].str.match(price_pattern)]
area_pattern = r'^((inform|request):area,){1}$'
area_tsne = tsne_bert[tsne_bert['state'].str.match(area_pattern)]
store_pattern = r'phone|address|name|postcode'
store_tsne = tsne_bert[tsne_bert['state'].str.contains(store_pattern) & ~tsne_bert['state'].str.contains('inform')]
joint_pattern = r'phone|address|name|postcode'
joint_tsne = tsne_bert[tsne_bert['state'].str.contains(joint_pattern) & tsne_bert['state'].str.contains('inform')]
etc_tsne = tsne_bert[~tsne_bert['state'].str.contains('request') & ~tsne_bert['state'].str.contains('inform')]

# %%
from bokeh.palettes import Pastel1

# create the plot and configure it
tsne_plot = figure(title='t-SNE BERT-large Sentence Embeddings - Level2: goal',
                   plot_width = 900,
                   plot_height = 600
                  ) #active_scroll='wheel_zoom'

colors = Pastel1[6]
tsne_plot.add_tools(HoverTool(tooltips = '@sentence'))
# adjust visual elements of the plot
tsne_plot.title.text_font_size = value('16pt')
tsne_plot.xaxis.visible = False
tsne_plot.yaxis.visible = False
tsne_plot.grid.grid_line_color = None
tsne_plot.outline_line_color = None


for i in range(6):
    plot_data = ''
    name = ''
    if i == 0:
        plot_data = ColumnDataSource(food_tsne)
        name = 'food'
    elif i == 1:
        plot_data = ColumnDataSource(price_tsne)
        name = 'price'
    elif i == 2:
        plot_data = ColumnDataSource(area_tsne)
        name = 'area'
    elif i == 3:
        plot_data = ColumnDataSource(store_tsne)
        name = 'store'
    elif i == 4:
        plot_data = ColumnDataSource(joint_tsne)
        name = 'joint'
    elif i == 5:
        plot_data = ColumnDataSource(etc_tsne)
        name = 'etc'
        
    tsne_plot.circle('x_coord', 'y_coord', source=plot_data,
                 #line_alpha=0.8, fill_alpha=0.1,
                 size=10, hover_line_color='black',
                 legend=name, color=colors[i]   
                )

tsne_plot.legend.location = "top_left"
tsne_plot.legend.click_policy="hide"

# show time!
show(tsne_plot);
# Out:
#   <div class="bk-root" id="768acf59-a01e-47ca-a7b7-1a560eb54857"></div>

# %% [markdown]
# ## 시각화 진행 - level 3: intent+goal별로 분류

# %%
food_pattern = r'^(request:food,){1}$' 
request_food = tsne_bert[tsne_bert['state'].str.match(food_pattern)]
#request_food.head()

area_pattern = r'^(request:area,){1}$' 
request_area = tsne_bert[tsne_bert['state'].str.match(area_pattern)]

price_pattern = r'^(request:price range,){1}$' 
request_price = tsne_bert[tsne_bert['state'].str.match(price_pattern)]

joint_pattern = r'^(request:(food|area|price range|phone|address|name|postcode),){2,}$' 
request_joint = tsne_bert[tsne_bert['state'].str.match(joint_pattern)]

# %%
food_pattern = r'^(inform:food,){1}$' 
inform_food = tsne_bert[tsne_bert['state'].str.match(food_pattern)]
#request_food.head()

area_pattern = r'^(inform:area,){1}$' 
inform_area = tsne_bert[tsne_bert['state'].str.match(area_pattern)]

price_pattern = r'^(inform:price range,){1}$' 
inform_price = tsne_bert[tsne_bert['state'].str.match(price_pattern)]

joint_pattern = r'^(inform:(food|area|price range|phone|address|name|postcode),){2,}$' 
inform_joint = tsne_bert[tsne_bert['state'].str.match(joint_pattern)]

# %%
joint_tsne = tsne_bert[tsne_bert['state'].str.contains('inform') & tsne_bert['state'].str.contains('request')]
etc_tsne = tsne_bert[~tsne_bert['state'].str.contains('request') & ~tsne_bert['state'].str.contains('inform')]

# %%
from bokeh.palettes import Paired

# create the plot and configure it
tsne_plot = figure(title='t-SNE BERT Sentence Embeddings - Level3: intent + goal',
                   plot_width = 900,
                   plot_height = 600
                  ) #active_scroll='wheel_zoom'

colors = Paired[10]
tsne_plot.add_tools(HoverTool(tooltips = '@sentence'))
# adjust visual elements of the plot
tsne_plot.title.text_font_size = value('16pt')
tsne_plot.xaxis.visible = False
tsne_plot.yaxis.visible = False
tsne_plot.grid.grid_line_color = None
tsne_plot.outline_line_color = None


for i in range(10):
    plot_data = ''
    name = ''
    if i == 0:
        plot_data = ColumnDataSource(request_food)
        name = 'request_food'
    elif i == 1:
        plot_data = ColumnDataSource(request_area)
        name = 'request_area'
    elif i == 2:
        plot_data = ColumnDataSource(request_price)
        name = 'request_price'
    elif i == 3:
        plot_data = ColumnDataSource(request_joint)
        name = 'request_joint'
    elif i == 4:
        plot_data = ColumnDataSource(inform_food)
        name = 'inform_food'
    elif i == 5:
        plot_data = ColumnDataSource(inform_area)
        name = 'inform_area'
    elif i == 6:
        plot_data = ColumnDataSource(inform_price)
        name = 'inform_price'
    elif i == 7:
        plot_data = ColumnDataSource(inform_joint)
        name = 'inform_joint'
    elif i == 8:
        plot_data = ColumnDataSource(joint_tsne)
        name = 'joint'
    elif i == 9:
        plot_data = ColumnDataSource(etc_tsne)
        name = 'etc'
        
    tsne_plot.circle('x_coord', 'y_coord', source=plot_data,
                 #line_alpha=0.8, fill_alpha=0.1,
                 size=10, hover_line_color='black',
                 legend=name, color=colors[i]   
                )

tsne_plot.legend.location = "top_left"
tsne_plot.legend.click_policy="hide"

# show time!
show(tsne_plot);
# Out:
#   <div class="bk-root" id="eedccbc6-4cef-46e7-a4e6-660c134c62ad"></div>
